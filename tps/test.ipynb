# %%
import tps
import pandas as pd

# %%
ds = tps.KSIData()
# Out:
# INFO:tps:loading csv data...
# INFO:tps:finish loading data

# %%
ds.df
# Out:
#                        Index_  ... STREET_U
# DATE_TIME                      ...
# 2006-01-02 07:05:00   3366651  ...   244622
# 2006-01-02 07:05:00   3366652  ...   244622
# 2006-01-04 19:40:00   3370333  ...  1197485
# 2006-01-04 19:40:00   3370334  ...  1197485
# 2006-01-06 22:10:00   3363337  ...   771730
# ...                       ...  ...      ...
# 2019-06-25 20:02:00  81278209  ...  1587599
# 2019-06-25 20:02:00  81278210  ...  1587599
# 2019-06-26 09:02:00  81270264  ...  2642860
# 2019-06-26 09:02:00  81270268  ...  2642860
# 2019-06-27 18:50:00  81278366  ...  1925850
#
# [6484 rows x 81 columns]

# %%
import numpy as np
pd.pivot_table(ds.df, index=['YEAR'], values=['AG_DRIV'], aggfunc=np.sum)
# Out:
#       AG_DRIV
# YEAR
# 2006      210
# 2007      188
# 2008      224
# 2009      208
# 2010      208
# 2011      195
# 2012      224
# 2013      246
# 2014      158
# 2015      153
# 2016      174
# 2017      161
# 2018      198
# 2019      139
